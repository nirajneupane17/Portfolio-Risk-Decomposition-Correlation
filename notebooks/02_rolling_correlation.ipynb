# %% [markdown]
# # 02 · Rolling Correlation & PC1 Systemic Risk
# **Project 10/10** | Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, matplotlib.pyplot as plt
from correlation_engine import rolling_correlation, pca_concentration
rets=pd.read_csv("../data/returns.csv",index_col="Date",parse_dates=True)
print("OK")

# %%
pca=pca_concentration(rets)
print(f"PC1 range: {pca.min()*100:.1f}% to {pca.max()*100:.1f}%")
print(f"COVID peak: {pca.loc["2020-02-01":"2020-05-31"].max()*100:.1f}%")

# %%
img=plt.imread("../results/02_rolling_correlation.png")
fig,ax=plt.subplots(figsize=(15,6)); ax.imshow(img); ax.axis("off"); plt.show()
