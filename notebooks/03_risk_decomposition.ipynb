# %% [markdown]
# # 03 · Risk Decomposition — Marginal & Component Contribution
# **Project 10/10** | Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from risk_decomposition import percent_risk_contribution, portfolio_stats
rets=pd.read_csv("../data/returns.csv",index_col="Date",parse_dates=True)
w=pd.read_csv("../data/portfolio_weights.csv",index_col="Asset")
wEW=w["equal_weight"].values; assets=list(rets.columns)
print("OK")

# %%
s=portfolio_stats(wEW,rets)
print(f"Ann Vol: {s['ann_vol']:.2f}%  Sharpe: {s['sharpe']:.3f}  MaxDD: {s['max_dd']:.2f}%")
print("\nRisk Contribution (%):")
[print(f"  {a}: {v:.2f}%") for a,v in zip(assets,s["prc"])]

# %%
img=plt.imread("../results/03_risk_decomposition.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()
