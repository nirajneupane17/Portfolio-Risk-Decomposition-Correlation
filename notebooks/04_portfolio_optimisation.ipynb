# %% [markdown]
# # 04 · Portfolio Optimisation — Efficient Frontier
# **Project 10/10** | Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, matplotlib.pyplot as plt
from risk_decomposition import min_variance_weights, max_sharpe_weights, risk_parity_weights, portfolio_stats
rets=pd.read_csv("../data/returns.csv",index_col="Date",parse_dates=True)
print("OK")

# %%
for nm,fn in [("Min Variance",min_variance_weights),("Max Sharpe",max_sharpe_weights),("Risk Parity",risk_parity_weights)]:
    w=fn(rets); s=portfolio_stats(w,rets)
    print(f"{nm}: Vol={s['ann_vol']:.2f}%  Sharpe={s['sharpe']:.3f}  MaxDD={s['max_dd']:.2f}%")

# %%
img=plt.imread("../results/04_portfolio_optimisation.png")
fig,ax=plt.subplots(figsize=(15,6)); ax.imshow(img); ax.axis("off"); plt.show()
